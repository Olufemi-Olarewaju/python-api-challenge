# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 583

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "https://api.openweathermap.org/data/2.5/weather"

# Set units of measurements to metric 
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Parameters
    params = {
        'q':city,
        'units':units,
        'appid':weather_api_key
    }
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    data = requests.get(base_url, params=params).json()

    try:
        # Parse the JSON and retrieve data
        city_weather = data['main']['temp']

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = data['coord']['lat']
        city_lng = data['coord']['lon']
        city_max_temp = data['main']['temp_max']
        city_humidity = data['main']['humidity']
        city_clouds = data['clouds']['all']
        city_wind = data['wind']['speed']
        city_country = data['sys']['country']
        city_date = time.ctime(data['dt'])

        # Append the City information into city_data list
        city_data.append({"City": city, 
                        "Lat": city_lat, 
                        "Lng": city_lng, 
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
            
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iskateley
# Processing Record 2 of Set 1 | imbituba
# Processing Record 3 of Set 1 | aasiaat
# Processing Record 4 of Set 1 | along
# Processing Record 5 of Set 1 | khandyga
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | san antonio de pale
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | otofuke
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | stanley
# Processing Record 12 of Set 1 | puerto natales
# Processing Record 13 of Set 1 | saipan
# Processing Record 14 of Set 1 | tumpat
# Processing Record 15 of Set 1 | kyabe
# Processing Record 16 of Set 1 | ust-nera
# Processing Record 17 of Set 1 | palotina
# Processing Record 18 of Set 1 | sinabang
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | waitangi
# Processing Record 21 of Set 1 | okha
# Processing Record 22 of Set 1 | bela
# Processing Record 23 of Set 1 | anadyr
# Processing Record 24 of Set 1 | hawaiian paradise park
# Processing Record 25 of Set 1 | fale old settlement
# Processing Record 26 of Set 1 | canmore
# Processing Record 27 of Set 1 | tsetserleg
# Processing Record 28 of Set 1 | hamilton
# Processing Record 29 of Set 1 | franceville
# Processing Record 30 of Set 1 | invercargill
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | whitehorse
# Processing Record 33 of Set 1 | ola
# Processing Record 34 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 1 | prince rupert
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 | teguise
# Processing Record 38 of Set 1 | padre bernardo
# Processing Record 39 of Set 1 | papatowai
# Processing Record 40 of Set 1 | edinburgh of the seven seas
# Processing Record 41 of Set 1 | kapuskasing
# Processing Record 42 of Set 1 | mugia
# Processing Record 43 of Set 1 | zhosaly
# Processing Record 44 of Set 1 | hotan
# Processing Record 45 of Set 1 | qaqortoq
# Processing Record 46 of Set 1 | menongue
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | muroto-misakicho
# Processing Record 49 of Set 1 | alik ghund
# Processing Record 50 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 0 of Set 2 | badiyah
# Processing Record 1 of Set 2 | wankaner
# Processing Record 2 of Set 2 | yarmouth
# Processing Record 3 of Set 2 | vila franca do campo
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | castillos
# Processing Record 6 of Set 2 | callao
# Processing Record 7 of Set 2 | kamogawa
# Processing Record 8 of Set 2 | walvis bay
# Processing Record 9 of Set 2 | port mathurin
# Processing Record 10 of Set 2 | dolores
# Processing Record 11 of Set 2 | coto de caza
# Processing Record 12 of Set 2 | terbuny
# Processing Record 13 of Set 2 | hammerfest
# Processing Record 14 of Set 2 | alderetes
# Processing Record 43 of Set 3 | carauari
# Processing Record 44 of Set 3 | olonkinbyen
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | susuman
# Processing Record 47 of Set 3 | juba
# Processing Record 48 of Set 3 | san antonio oeste
# Processing Record 49 of Set 3 | kittila
# Processing Record 0 of Set 4 | krasnyy chikoy
# Processing Record 1 of Set 4 | floro
# Processing Record 2 of Set 4 | haiku-pauwela
# Processing Record 3 of Set 4 | isla mujeres
# Processing Record 4 of Set 4 | colonia
# Processing Record 5 of Set 4 | sur
# Processing Record 6 of Set 4 | avarua
# Processing Record 7 of Set 4 | nakhon si thammarat
# Processing Record 8 of Set 4 | kitee
# Processing Record 9 of Set 4 | rio de janeiro
# Processing Record 10 of Set 4 | solleftea
# Processing Record 11 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 12 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 13 of Set 4 | bubaque
# Processing Record 14 of Set 4 | tazacorte
# Processing Record 15 of Set 4 | kingston
# Processing Record 16 of Set 4 | crucecita
# Processing Record 17 of Set 4 | lensk
# Processing Record 18 of Set 4 | tindouf
# Processing Record 19 of Set 4 | goure
# Processing Record 20 of Set 4 | barah
# Processing Record 21 of Set 4 | chonchi
# Processing Record 22 of Set 4 | oriximina
# Processing Record 23 of Set 4 | point pedro
# Processing Record 24 of Set 4 | loango
# Processing Record 25 of Set 4 | gannan
# Processing Record 26 of Set 4 | saint-philippe
# Processing Record 27 of Set 4 | dzuunmod
# Processing Record 28 of Set 4 | isafjordur
# Processing Record 29 of Set 4 | weno
# Processing Record 30 of Set 4 | deschutes river woods
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | kuanda
# Processing Record 33 of Set 4 | sarakhs
# Processing Record 34 of Set 4 | nema
# Processing Record 35 of Set 4 | san patricio
# Processing Record 36 of Set 4 | vorgashor
# Processing Record 37 of Set 4 | kristiansund
# Processing Record 38 of Set 4 | vicente guerrero
# Processing Record 39 of Set 4 | joao pessoa
# Processing Record 40 of Set 4 | praia
# Processing Record 41 of Set 4 | nogliki
# Processing Record 42 of Set 4 | ontario
# Processing Record 43 of Set 4 | utrik
# Processing Record 44 of Set 4 | taro
# Processing Record 45 of Set 4 | mwinilunga
# Processing Record 46 of Set 4 | bandarbeyla
# Processing Record 47 of Set 4 | nar'yan-mar
# Processing Record 48 of Set 4 | valdivia
# Processing Record 49 of Set 4 | pirenopolis
# Processing Record 0 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 5 | kourou
# Processing Record 2 of Set 5 | tazovsky
# Processing Record 3 of Set 5 | eugene
# Processing Record 4 of Set 5 | grand baie
# Processing Record 5 of Set 5 | nagqu
# Processing Record 6 of Set 5 | koungheul
# Processing Record 7 of Set 5 | turpan
# Processing Record 8 of Set 5 | isangel
# Processing Record 9 of Set 5 | taiohae
# City not found. Skipping...
# Processing Record 10 of Set 5 | minas de marcona
# Processing Record 11 of Set 5 | grand falls-windsor
# Processing Record 12 of Set 5 | enewetak
# Processing Record 13 of Set 5 | lazaro cardenas
# Processing Record 14 of Set 5 | kismayo
# Processing Record 15 of Set 5 | le morne-rouge
# Processing Record 16 of Set 5 | anabar
# City not found. Skipping...
# Processing Record 17 of Set 5 | badger
# Processing Record 18 of Set 5 | sao vicente
# Processing Record 19 of Set 5 | dryden
# Processing Record 20 of Set 5 | seogwipo
# City not found. Skipping...
# Processing Record 21 of Set 5 | flying fish cove
# Processing Record 22 of Set 5 | opuwo
# Processing Record 23 of Set 5 | fort bragg
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | ha'il
# Processing Record 26 of Set 5 | wailua homesteads
# Processing Record 27 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 28 of Set 5 | salalah
# Processing Record 29 of Set 5 | vernon
# Processing Record 30 of Set 5 | whangarei
# Processing Record 31 of Set 5 | kendari
# Processing Record 32 of Set 5 | mitu
# Processing Record 33 of Set 5 | miyaly
# Processing Record 34 of Set 5 | dadukou
# Processing Record 35 of Set 5 | gornozavodsk
# Processing Record 36 of Set 5 | cooma
# Processing Record 37 of Set 5 | gaalkacyo
# Processing Record 38 of Set 5 | monteros
# Processing Record 39 of Set 5 | la passe
# Processing Record 40 of Set 5 | puerto libertad
# Processing Record 41 of Set 5 | bosaso
# Processing Record 42 of Set 5 | urucui
# Processing Record 43 of Set 5 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 44 of Set 5 | el porvenir
# Processing Record 45 of Set 5 | hasaki
# Processing Record 46 of Set 5 | alvorada
# Processing Record 47 of Set 5 | chiang saen
# Processing Record 48 of Set 5 | tofol
# Processing Record 49 of Set 5 | bilibino
# Processing Record 0 of Set 6 | posto fiscal rolim de moura
# Processing Record 1 of Set 6 | lapeer
# Processing Record 2 of Set 6 | lebu
# Processing Record 3 of Set 6 | st. john's
# Processing Record 4 of Set 6 | kavaratti
# Processing Record 5 of Set 6 | alpine
# Processing Record 6 of Set 6 | puerto cabezas
# Processing Record 7 of Set 6 | sarina
# Processing Record 8 of Set 6 | taos
# Processing Record 9 of Set 6 | cockburn town
# Processing Record 10 of Set 6 | porto novo
# Processing Record 11 of Set 6 | muisne
# Processing Record 12 of Set 6 | doetinchem
# Processing Record 13 of Set 6 | brak
# Processing Record 14 of Set 6 | nemuro
# Processing Record 15 of Set 6 | quesnel
# Processing Record 16 of Set 6 | hit
# Processing Record 17 of Set 6 | tralee
# Processing Record 18 of Set 6 | argo
# Processing Record 19 of Set 6 | strelka
# Processing Record 20 of Set 6 | suva
# Processing Record 21 of Set 6 | sao joao da barra
# Processing Record 22 of Set 6 | kill devil hills
# Processing Record 23 of Set 6 | angaur state
# Processing Record 24 of Set 6 | longyearbyen
# Processing Record 25 of Set 6 | aleksandrovsk-sakhalinskiy
# Processing Record 26 of Set 6 | belaya glina
# Processing Record 27 of Set 6 | kandyagash
# Processing Record 28 of Set 6 | atafu village
# Processing Record 29 of Set 6 | mount gambier
# Processing Record 30 of Set 6 | crane
# Processing Record 31 of Set 6 | vilyuchinsk
# Processing Record 32 of Set 6 | mar del plata
# Processing Record 33 of Set 6 | kletskaya
# Processing Record 34 of Set 6 | beira
# Processing Record 35 of Set 6 | pandan
# Processing Record 36 of Set 6 | fort st. john
# Processing Record 37 of Set 6 | panama city beach
# Processing Record 38 of Set 6 | bereket
# Processing Record 39 of Set 6 | codrington
# Processing Record 40 of Set 6 | ornskoldsvik
# Processing Record 41 of Set 6 | zaysan
# Processing Record 42 of Set 6 | chibougamau
# Processing Record 43 of Set 6 | puerto deseado
# Processing Record 44 of Set 6 | puerto san jose
# Processing Record 45 of Set 6 | afaahiti
# Processing Record 46 of Set 6 | bathsheba
# Processing Record 47 of Set 6 | kayangel
# Processing Record 48 of Set 6 | la sarre
# Processing Record 49 of Set 6 | quellon
# Processing Record 0 of Set 7 | alpena
# Processing Record 1 of Set 7 | howrah
# Processing Record 2 of Set 7 | ujae
# Processing Record 3 of Set 7 | sarupathar
# Processing Record 4 of Set 7 | samdrup jongkhar
# Processing Record 5 of Set 7 | lianzhou
# Processing Record 6 of Set 7 | khadan khak
# Processing Record 7 of Set 7 | al mutayrifi
# Processing Record 8 of Set 7 | elmendorf air force base
# City not found. Skipping...
# Processing Record 9 of Set 7 | uturoa
# Processing Record 10 of Set 7 | kokshetau
# Processing Record 11 of Set 7 | alamogordo
# Processing Record 12 of Set 7 | kolyshley
# Processing Record 13 of Set 7 | yonggang-up
# Processing Record 14 of Set 7 | oum hadjer
# Processing Record 15 of Set 7 | kirs
# Processing Record 16 of Set 7 | cabo san lucas
# Processing Record 17 of Set 7 | tsiombe
# Processing Record 18 of Set 7 | shenkursk
# Processing Record 19 of Set 7 | tayu
# Processing Record 20 of Set 7 | talnakh
# Processing Record 21 of Set 7 | capitao poco
# Processing Record 22 of Set 7 | muang phon-hong
# Processing Record 23 of Set 7 | peace river
# Processing Record 24 of Set 7 | curillo
# Processing Record 25 of Set 7 | qarazhal
# Processing Record 26 of Set 7 | broken hill
# Processing Record 27 of Set 7 | yangambi
# Processing Record 28 of Set 7 | nur-sultan
# Processing Record 29 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 30 of Set 7 | sydney
# Processing Record 31 of Set 7 | konce
# Processing Record 32 of Set 7 | marsh harbour
# Processing Record 33 of Set 7 | hadibu
# Processing Record 34 of Set 7 | poli
# Processing Record 35 of Set 7 | camarinas
# Processing Record 36 of Set 7 | margaret river
# Processing Record 37 of Set 7 | christchurch
# Processing Record 38 of Set 7 | robertsganj
# Processing Record 39 of Set 7 | thakhek
# Processing Record 40 of Set 7 | alaghsas
# Processing Record 41 of Set 7 | hirara
# Processing Record 42 of Set 7 | shelbyville
# Processing Record 43 of Set 7 | amga
# Processing Record 44 of Set 7 | as samawah
# Processing Record 45 of Set 7 | concepcion del oro
# Processing Record 46 of Set 7 | saldanha
# Processing Record 47 of Set 7 | pursat
# Processing Record 48 of Set 7 | fortuna
# Processing Record 49 of Set 7 | duki
# Processing Record 0 of Set 8 | mount pearl
# Processing Record 1 of Set 8 | sorong
# Processing Record 2 of Set 8 | trairi
# Processing Record 3 of Set 8 | kananga
# Processing Record 4 of Set 8 | kulhudhuffushi
# Processing Record 5 of Set 8 | taulaga
# Processing Record 6 of Set 8 | caluula
# Processing Record 7 of Set 8 | vaijapur
# Processing Record 8 of Set 8 | pickering
# Processing Record 9 of Set 8 | san julian
# Processing Record 10 of Set 8 | saki
# Processing Record 11 of Set 8 | usogorsk
# Processing Record 12 of Set 8 | mohammedia
# Processing Record 13 of Set 8 | puerto baquerizo moreno
# Processing Record 14 of Set 8 | champerico
# Processing Record 15 of Set 8 | kyaikkami
# Processing Record 38 of Set 9 | vanimo
# Processing Record 39 of Set 9 | val-d'or
# Processing Record 40 of Set 9 | orosei
# Processing Record 41 of Set 9 | nizao
# Processing Record 42 of Set 9 | ain temouchent
# Processing Record 43 of Set 9 | camapua
# Processing Record 44 of Set 9 | wanning
# Processing Record 45 of Set 9 | bielsk podlaski
# Processing Record 46 of Set 9 | banda aceh
# Processing Record 47 of Set 9 | tromso
# Processing Record 48 of Set 9 | port saint john's
# Processing Record 49 of Set 9 | yahyali
# Processing Record 0 of Set 10 | brigantine
# Processing Record 1 of Set 10 | elk
# Processing Record 2 of Set 10 | irati
# Processing Record 3 of Set 10 | yichun
# Processing Record 4 of Set 10 | lodeynoye pole
# Processing Record 5 of Set 10 | eraan
# Processing Record 6 of Set 10 | malango
# Processing Record 7 of Set 10 | boca do acre
# Processing Record 8 of Set 10 | pansemal
# Processing Record 9 of Set 10 | kavieng
# Processing Record 10 of Set 10 | an nuhud
# Processing Record 11 of Set 10 | mogadishu
# Processing Record 12 of Set 10 | airway heights
# Processing Record 13 of Set 10 | rongelap
# Processing Record 14 of Set 10 | balaklava
# Processing Record 15 of Set 10 | cheongju-si
# Processing Record 16 of Set 10 | brcko
# Processing Record 17 of Set 10 | la gi
# Processing Record 18 of Set 10 | nishinoomote
# Processing Record 19 of Set 10 | rudbar
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | kindu
# Processing Record 22 of Set 10 | colon
# Processing Record 23 of Set 10 | tieli
# Processing Record 24 of Set 10 | khanty-mansiysk
# Processing Record 25 of Set 10 | kas
# Processing Record 26 of Set 10 | singkil
# Processing Record 27 of Set 10 | nykobing falster
# Processing Record 28 of Set 10 | vorkuta
# Processing Record 29 of Set 10 | kodinsk
# Processing Record 30 of Set 10 | tefe
# Processing Record 31 of Set 10 | pesqueira
# Processing Record 32 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 33 of Set 10 | progreso
# Processing Record 34 of Set 10 | mukhorshibir'
# City not found. Skipping...
# Processing Record 35 of Set 10 | sumbawa besar
# Processing Record 36 of Set 10 | wenshang
# Processing Record 37 of Set 10 | esquel
# Processing Record 38 of Set 10 | kijang
# Processing Record 39 of Set 10 | ormara
# Processing Record 40 of Set 10 | rosso
# Processing Record 41 of Set 10 | ust-tsilma
# Processing Record 42 of Set 10 | bismil
# Processing Record 43 of Set 10 | dudinka
# Processing Record 44 of Set 10 | la'ie
# Processing Record 45 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 46 of Set 10 | ventspils
# Processing Record 47 of Set 10 | haicheng
# Processing Record 48 of Set 10 | hami
# Processing Record 49 of Set 10 | morant bay
# Processing Record 0 of Set 11 | marion
# Processing Record 1 of Set 11 | hede
# Processing Record 2 of Set 11 | sitka
# Processing Record 3 of Set 11 | palmer
# Processing Record 4 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 5 of Set 11 | qamdo
# Processing Record 6 of Set 11 | chos malal
# Processing Record 7 of Set 11 | novyy turtkul'
# Processing Record 8 of Set 11 | maqat
# Processing Record 9 of Set 11 | bankim
# Processing Record 10 of Set 11 | adh dhibiyah
# City not found. Skipping...
# Processing Record 11 of Set 11 | dyat'kovo
# Processing Record 12 of Set 11 | apac
# Processing Record 13 of Set 11 | zelenoborskiy
# Processing Record 14 of Set 11 | yuzhno-kurilsk
# Processing Record 15 of Set 11 | miyanoura
# City not found. Skipping...
# Processing Record 16 of Set 11 | acajutla
# Processing Record 17 of Set 11 | tshabong
# Processing Record 18 of Set 11 | khatra
# Processing Record 19 of Set 11 | novaya usman'
# Processing Record 20 of Set 11 | soure
# Processing Record 21 of Set 11 | nurota
# Processing Record 22 of Set 11 | andratx
# Processing Record 23 of Set 11 | bamboo flat
# Processing Record 24 of Set 11 | westport
# Processing Record 25 of Set 11 | lethbridge
# Processing Record 26 of Set 11 | chesma
# Processing Record 27 of Set 11 | alofi
# Processing Record 28 of Set 11 | nuku'alofa
# Processing Record 29 of Set 11 | plasnica
# Processing Record 30 of Set 11 | kichmengskiy gorodok
# Processing Record 31 of Set 11 | cortez
# Processing Record 32 of Set 11 | santa ana
# Processing Record 33 of Set 11 | mount isa
# Processing Record 34 of Set 11 | al ghayzah
# Processing Record 35 of Set 11 | dickinson
# Processing Record 36 of Set 11 | mandalgovi
# Processing Record 37 of Set 11 | puerto madryn
# Processing Record 38 of Set 11 | remire-montjoly
# Processing Record 39 of Set 11 | coquimbo
# Processing Record 40 of Set 11 | puke
# Processing Record 41 of Set 11 | port augusta
# Processing Record 42 of Set 11 | port-cartier
# Processing Record 43 of Set 11 | saint-louis
# Processing Record 44 of Set 11 | auchi
# Processing Record 45 of Set 11 | kiruna
# Processing Record 46 of Set 11 | pingliang
# Processing Record 47 of Set 11 | tabou
# Processing Record 48 of Set 11 | kangding
# Processing Record 49 of Set 11 | moroto
# Processing Record 0 of Set 12 | enoch
# Processing Record 1 of Set 12 | bengkulu
# Processing Record 2 of Set 12 | margate
# Processing Record 3 of Set 12 | ahau
# City not found. Skipping...
# Processing Record 4 of Set 12 | tambura
# Processing Record 5 of Set 12 | corfu
# Processing Record 6 of Set 12 | kolosovka
# Processing Record 7 of Set 12 | tamandare
# Processing Record 8 of Set 12 | lionel town
# Processing Record 9 of Set 12 | kapa'a
# Processing Record 10 of Set 12 | the pas
# Processing Record 11 of Set 12 | iraquara
# Processing Record 12 of Set 12 | salahonda
# Processing Record 13 of Set 12 | pergamino
# Processing Record 14 of Set 12 | byron bay
# Processing Record 15 of Set 12 | phan rang-thap cham
# Processing Record 16 of Set 12 | pacific grove
# Processing Record 17 of Set 12 | lusaka
# Processing Record 18 of Set 12 | pathein
# Processing Record 19 of Set 12 | kabare
# Processing Record 20 of Set 12 | najran
# Processing Record 21 of Set 12 | lhuentse
# Processing Record 22 of Set 12 | ferkessedougou
# Processing Record 23 of Set 12 | arauca
# Processing Record 24 of Set 12 | banda
# Processing Record 25 of Set 12 | urcos
# Processing Record 26 of Set 12 | cidreira
# Processing Record 27 of Set 12 | pimenta bueno
# Processing Record 28 of Set 12 | ulladulla
# Processing Record 29 of Set 12 | chechen-aul
# Processing Record 30 of Set 12 | guiuan
# Processing Record 31 of Set 12 | yatou
# Processing Record 32 of Set 12 | humberto de campos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  iskateley  67.6803   53.1512     -7.77        96         100        4.02
# 1   imbituba -28.2400  -48.6703     24.36        96         100        2.37
# 2    aasiaat  68.7098  -52.8699     -9.46        85          99        2.09
# 3      along  28.1667   94.7667     15.95        65          89        0.85
# 4   khandyga  62.6667  135.6000    -30.93        99          59        1.54
#
#   Country                      Date
# 0      RU  Tue Nov 14 11:19:03 2023
# 1      BR  Tue Nov 14 11:19:04 2023
# 2      GL  Tue Nov 14 11:19:05 2023
# 3      IN  Tue Nov 14 11:19:06 2023
# 4      RU  Tue Nov 14 11:19:07 2023

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        iskateley  67.6803   53.1512     -7.77        96         100
# 1         imbituba -28.2400  -48.6703     24.36        96         100
# 2          aasiaat  68.7098  -52.8699     -9.46        85          99
# 3            along  28.1667   94.7667     15.95        65          89
# 4         khandyga  62.6667  135.6000    -30.93        99          59
#
#          Wind Speed Country                      Date
# City_ID
# 0              4.02      RU  Tue Nov 14 11:19:03 2023
# 1              2.37      BR  Tue Nov 14 11:19:04 2023
# 2              2.09      GL  Tue Nov 14 11:19:05 2023
# 3              0.85      IN  Tue Nov 14 11:19:06 2023
# 4              1.54      RU  Tue Nov 14 11:19:07 2023

# %% [markdown]
# ### Create the Scatter Plots Requested

# %%
# A function that returns the scatter plots for x vs. y
def weather_plot(x, y):
    
    # Build scatter plot for x vs. y
    city_data_df.plot(x, y, kind='scatter', s = 40, edgecolors = 'black', alpha = 0.7, grid=True)

    # Variable to hold date displayed on plot title
    date= f"({time.localtime().tm_year}-{time.localtime().tm_mon}-{time.localtime().tm_mday})"

    # Incorporate the other graph properties and save the figure
    plt.xlabel("Latitude")
    if y == "Max Temp":
        plt.ylabel("Max Temperatures (C)")
        plt.title(f"City Latitude vs. Max Temperature {date}")
        plt.savefig("output_data/Fig1.png")
    elif y == "Humidity":
        plt.ylabel("Humidity (%)")
        plt.title(f"City Latitude vs. Humidity {date}")
        plt.savefig("output_data/Fig2.png")        
    elif y == "Cloudiness":
        plt.ylabel("Cloudiness (%)")
        plt.title(f"City Latitude vs. Cloudiness {date}")
        plt.savefig("output_data/Fig3.png")        
    elif y == "Wind Speed":
        plt.ylabel("Wind Speed (m/s)")
        plt.title(f"City Latitude vs. Wind Speed {date}")
        plt.savefig("output_data/Fig4.png")
        
    # Show plot
    plt.show()

    return

# %% [markdown]
# #### Latitude Vs. Temperature

# %%
# Customize function to return the scatter plots for Latitude vs. Temperature
weather_plot('Lat', 'Max Temp')

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Customize function to return the scatter plots for Latitude vs. Humidity
weather_plot('Lat', 'Humidity')

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Customize function to return the scatter plots for Latitude vs. Cloudiness
weather_plot('Lat', 'Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Customize function to return the scatter plots for Latitude vs. Wind Speed
weather_plot('Lat', 'Wind Speed')

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        iskateley  67.6803   53.1512     -7.77        96         100
# 2          aasiaat  68.7098  -52.8699     -9.46        85          99
# 3            along  28.1667   94.7667     15.95        65          89
# 4         khandyga  62.6667  135.6000    -30.93        99          59
# 8          otofuke  42.9917  143.2003     -1.69        82          11
#
#          Wind Speed Country                      Date
# City_ID
# 0              4.02      RU  Tue Nov 14 11:19:03 2023
# 2              2.09      GL  Tue Nov 14 11:19:05 2023
# 3              0.85      IN  Tue Nov 14 11:19:06 2023
# 4              1.54      RU  Tue Nov 14 11:19:07 2023
# 8              2.53      JP  Tue Nov 14 11:19:10 2023

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 1                   imbituba -28.2400 -48.6703     24.36        96
# 5               punta arenas -53.1500 -70.9167      8.06        53
# 6        san antonio de pale  -1.4014   5.6325     26.68        81
# 7          port-aux-francais -49.3500  70.2167      2.71        96
# 9                  grytviken -54.2811 -36.5092      3.47        91
#
#          Cloudiness  Wind Speed Country                      Date
# City_ID
# 1               100        2.37      BR  Tue Nov 14 11:19:04 2023
# 5                40        8.75      CL  Tue Nov 14 11:19:07 2023
# 6                21        5.87      GQ  Tue Nov 14 11:19:08 2023
# 7               100        8.88      TF  Tue Nov 14 11:19:09 2023
# 9                99        0.99      GS  Tue Nov 14 11:19:10 2023

# %%
# Define a function to create Linear Regression plots
def weather_linregress_plot(x, y, df):
    
    
    # Build scatter plot for x vs. y
    df.plot(x, y, kind='scatter', s = 30)

    # Calculate Linear Regression
    (slope, intercept, rvalue, pvalue, stderr)= linregress(df[x], df[y])
    
    #Print r-value
    print(f"The r-value is: {rvalue}")

    # Linear Regression formular
    regress_line = (slope * df[x] ) + intercept

    # Plot Linear Regression line and annotate the equation on the plot
    plt.plot(df[x], regress_line, color = 'red')
    
    # If statements to determine if plot is for Northern Hemisphere or Southern Hemisphere
    if len(list(df[x]))== len(list(northern_hemi_df[x])):
        plt.annotate(f"y = {round(slope, 2)}x + {round(intercept, 2)}", (45, 12), fontsize = 15, color = 'red')
    elif len(list(df[x]))== len(list(southern_hemi_df[x])):
        plt.annotate(f"y = {round(slope, 2)}x + {round(intercept, 2)}", (-45, 10), fontsize = 15, color = 'red')

    # Incorporate the other graph properties and save the figure
    plt.xlabel("Latitude")
    if y == "Max Temp":
        plt.ylabel("Max Temperatures (C)")
        

    elif y == "Humidity":
        plt.ylabel("Humidity (%)")
        

    elif y == "Cloudiness":
        plt.ylabel("Cloudiness (%)")
        

    elif y == "Wind Speed":
        plt.ylabel("Wind Speed (m/s)")

    # Show plot
    plt.show()

    return

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
weather_linregress_plot('Lat', 'Max Temp', northern_hemi_df)
# Out:
# The r-value is: -0.8726627323236387

# %%
# Linear regression on Southern Hemisphere
weather_linregress_plot('Lat', 'Max Temp', southern_hemi_df)
# Out:
# The r-value is: 0.6926957200555972

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
weather_linregress_plot('Lat', 'Humidity', northern_hemi_df)
# Out:
# The r-value is: 0.3100750463972183

# %%
# Southern Hemisphere
weather_linregress_plot('Lat', 'Humidity', southern_hemi_df)
# Out:
# The r-value is: 0.019602745950695645

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
weather_linregress_plot('Lat', 'Cloudiness', northern_hemi_df)
# Out:
# The r-value is: 0.140769442094745

# %%
# Southern Hemisphere
weather_linregress_plot('Lat', 'Cloudiness', southern_hemi_df)
# Out:
# The r-value is: 0.10659465066527589

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
weather_linregress_plot('Lat', 'Wind Speed', northern_hemi_df)
# Out:
# The r-value is: 0.024679282758214665

# %%
# Southern Hemisphere
weather_linregress_plot('Lat', 'Wind Speed', southern_hemi_df)
# Out:
# The r-value is: -0.25250276271275085

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
