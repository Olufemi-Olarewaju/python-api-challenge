# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pprint import pprint

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  iskateley  67.6803   53.1512     -7.77        96         100
# 1        1   imbituba -28.2400  -48.6703     24.36        96         100
# 2        2    aasiaat  68.7098  -52.8699     -9.46        85          99
# 3        3      along  28.1667   94.7667     15.95        65          89
# 4        4   khandyga  62.6667  135.6000    -30.93        99          59
#
#    Wind Speed Country                      Date
# 0        4.02      RU  Tue Nov 14 11:19:03 2023
# 1        2.37      BR  Tue Nov 14 11:19:04 2023
# 2        2.09      GL  Tue Nov 14 11:19:05 2023
# 3        0.85      IN  Tue Nov 14 11:19:06 2023
# 4        1.54      RU  Tue Nov 14 11:19:07 2023

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
humidity_map = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = 'OSM',
    frame_width = 800,
    frame_height = 600,
    size = 'Humidity',
    scale = 1,
    color = 'City',
    hover_cols = ['Max Temp', 'Country']    
)

# Display the map
humidity_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Max Temp,Country)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# Criteria: Moderately High Temperature, Low Humidity
vacation_df = city_data_df.loc[(city_data_df['Max Temp']>= 25) & (city_data_df['Max Temp']<27), :]
vacation_df = vacation_df.sort_values(by='Humidity', ascending=True)
# Drop any rows with null values
vacation_df = vacation_df.dropna()
# Display sample data
vacation_df = vacation_df[['City_ID', 'City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]
vacation_df
# Out:
#      City_ID                 City Country      Lat       Lng  Max Temp  \
# 364      364             san luis      AR -33.2950  -66.3356     26.43
# 390      390        alice springs      AU -23.7000  133.8833     25.75
# 538      538            pergamino      AR -33.8900  -60.5736     25.10
# 50        50             wankaner      IN  22.6167   70.9333     25.16
# 424      424       ain temouchent      DZ  35.2975   -1.1404     25.02
# 469      469               ormara      PK  25.2088   64.6357     26.07
# 152      152                  sur      OM  22.5667   59.5289     25.15
# 63        63            alderetes      AR -26.8167  -65.1333     25.95
# 404      404               gebeit      SD  21.0667   36.3167     26.42
# 233      233          el porvenir      HN  13.7617  -87.3458     26.63
# 290      290               howrah      IN  22.5892   88.3103     25.00
# 319      319        marsh harbour      BS  26.5412  -77.0636     25.64
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = vacation_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity']]

# Add an empty column, "Hotel Name", to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
# C:\Users\100676677\AppData\Local\Temp\ipykernel_16832\706867647.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ''
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 364             san luis      AR -33.2950  -66.3356     26.43        20
# 390        alice springs      AU -23.7000  133.8833     25.75        27
# 538            pergamino      AR -33.8900  -60.5736     25.10        31
# 50              wankaner      IN  22.6167   70.9333     25.16        32
# 424       ain temouchent      DZ  35.2975   -1.1404     25.02        36
# 469               ormara      PK  25.2088   64.6357     26.07        49
# 152                  sur      OM  22.5667   59.5289     25.15        49
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = 'accommodation.hotel'
params = {
    'apiKey':geoapify_key,
    'categories':categories
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get city name, latitude, longitude from the DataFrame
    # city = hotel_df.loc[index, 'City']
    latitude = f"{hotel_df.loc[index, 'Lat']}"
    longitude = f"{hotel_df.loc[index, 'Lng']}"

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    # params["name"] = f"{city}"
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# san luis - nearest hotel: Hotel Dos Venados
# alice springs - nearest hotel: Aurora Alice Springs
# pergamino - nearest hotel: SIMOCA
# wankaner - nearest hotel: No hotel found
# ain temouchent - nearest hotel: Hôtel Restaurant Zeidour
# ormara - nearest hotel: No hotel found
# sur - nearest hotel: Sur Hotel
# alderetes - nearest hotel: Sheraton Tucuman Hotel
# gebeit - nearest hotel: No hotel found
# el porvenir - nearest hotel: No hotel found
# howrah - nearest hotel: Sun India Guest House
# marsh harbour - nearest hotel: Lofty Fig Villas
# bankim - nearest hotel: No hotel found
# kavieng - nearest hotel: Kavieng Hotel
# port mathurin - nearest hotel: Escale Vacances
# west island - nearest hotel: Cocos Village Bungalows
# beira - nearest hotel: Hotel Savoy
# muisne - nearest hotel: Hostal Té de Menta
# san antonio de pale - nearest hotel: No hotel found
# colon - nearest hotel: Hotel Plaza
# mahina - nearest hotel: Motu Martin
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Reconfigured map
vacation_cities_map = hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = 'OSM',
    frame_width = 800,
    frame_height = 600,
    size = 'Humidity',
    scale = 1,
    color = 'City',
    hover_cols = ['Max Temp', 'Hotel Name', 'Country']    
)

# Display the map
vacation_cities_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Max Temp,Hotel Name,Country)
